# %%
import numpy as np
import pandas as pd

# %%
books = pd.read_csv("books.csv")

# To make a new column with values that are all the same,
# do the following. Name the column, and assign it to a single
# default value. This will populate every row with that value.
#books['book-link'] = '#'
books['book-path'] = 'assets/book_image/No_image.jpg'
books['book-link'] = '#'

books.to_csv('books.csv', index=False)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
books=pd.read_csv("books.csv")

# %%
#books=pd.read_csv('books.csv')
users=pd.read_csv('users.csv')
ratings=pd.read_csv('ratings.csv')
ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
ratings_with_name=ratings.merge(books, on='ISBN')

# %%
ratings_with_name
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1           2313  034545104X            5
# 2           6543  034545104X            0
# 3           8680  034545104X            5
# 4          10314  034545104X            9
# ...          ...         ...          ...
# 1031131   276688  0517145553            0
# 1031132   276688  1575660792            7
# 1031133   276690  0590907301            0
# 1031134   276704  0679752714            0
# 1031135   276704  0806917695            5
#
#                                                 Book-Title      Book-Author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# 2                                     Flesh Tones: A Novel       M. J. Rose
# 3                                     Flesh Tones: A Novel       M. J. Rose
# ...

# %%
num_rating_df=ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
num_rating_df
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
avg_rating_df=ratings_with_name.groupby('Book-Title').mean()['Book-Rating'].reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg_ratings'},inplace=True)
avg_rating_df
# Out:
#                                                Book-Title  avg_ratings
# 0        A Light in the Storm: The Civil War Diary of ...     2.250000
# 1                                   Always Have Popsicles     0.000000
# 2                    Apple Magic (The Collector's series)     0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...     8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...     0.000000
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.     0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.     5.250000
# 241068                                Ã?Â?sterlich leben.     7.000000
# 241069                              Ã?Â?stlich der Berge.     2.666667
# 241070                                  Ã?Â?thique en toc     4.000000
#
# [241071 rows x 2 columns]

# %%
popular_df=num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
#         avg_ratings
# 0          2.250000
# 1          0.000000
# 2          0.000000
# 3          8.000000
# ...

# %%
popular_df[popular_df['num_ratings']>=250]
# Out:
#                                                Book-Title  num_ratings  \
# 764                                                  1984          284
# 818                                   1st to Die: A Novel          509
# 1048                                           2nd Chance          356
# 1760                                   A Bend in the Road          346
# 2281    A Child Called \It\": One Child's Courage to S...          265
# ...                                                   ...          ...
# 233850                           White Oleander : A Novel          387
# 233851       White Oleander : A Novel (Oprah's Book Club)          356
# 234740  Wicked: The Life and Times of the Wicked Witch...          326
# 234951                                        Wild Animus         2502
# 240860                                \O\" Is for Outlaw"          269
#
#         avg_ratings
# 764        4.454225
# 818        3.575639
# 1048       3.269663
# 1760       3.364162
# ...

# %%
popular_df=popular_df[popular_df['num_ratings']>=250].sort_values('avg_ratings',ascending=False).head(50)
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 80422        Harry Potter and the Goblet of Fire (Book 4)          387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)          278
# 80426   Harry Potter and the Order of the Phoenix (Boo...          347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)          556
# 191612  The Hobbit : The Enchanting Prelude to The Lor...          281
# 187377  The Fellowship of the Ring (The Lord of the Ri...          368
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...          575
# 211384     The Two Towers (The Lord of the Rings, Part 2)          260
# 219741                              To Kill a Mockingbird          510
# 183573                                  The Da Vinci Code          898
# 187880                 The Five People You Meet in Heaven          430
# ...

# %%
popular_df=popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','book-path','num_ratings','avg_ratings','book-link']]

# %%
popular_df.at[0, 'book-link'] = 'https://www.goodreads.com/book/show/5.Harry_Potter_and_the_Prisoner_of_Azkaban'
popular_df.at[3, 'book-link'] = 'https://www.goodreads.com/book/show/6.Harry_Potter_and_the_Goblet_of_Fire'
popular_df.at[5, 'book-link'] = 'https://www.goodreads.com/book/show/3.Harry_Potter_and_the_Sorcerer_s_Stone'
popular_df.at[9, 'book-link'] = 'https://www.goodreads.com/book/show/2.Harry_Potter_and_the_Order_of_the_Phoenix'
popular_df.at[13, 'book-link'] = 'https://www.goodreads.com/book/show/15881.Harry_Potter_and_the_Chamber_of_Secrets'
popular_df.at[16, 'book-link'] = 'https://www.goodreads.com/book/show/2267890.The_Hobbit'
popular_df.at[17, 'book-link'] = 'https://www.goodreads.com/book/show/61215351-the-fellowship-of-the-ring'
popular_df.at[26, 'book-link'] = 'https://www.goodreads.com/book/show/3.Harry_Potter_and_the_Sorcerer_s_Stone'
popular_df.at[28, 'book-link'] = 'https://www.goodreads.com/book/show/569712.The_Lord_of_the_Rings'
popular_df.at[39, 'book-link'] = 'https://www.goodreads.com/book/show/2657.To_Kill_a_Mockingbird'
popular_df.at[47, 'book-link'] = 'https://www.goodreads.com/book/show/968.The_Da_Vinci_Code'
popular_df.at[53, 'book-link'] = 'https://www.goodreads.com/book/show/3431.The_Five_People_You_Meet_in_Heaven'
popular_df.at[55, 'book-link'] = 'https://www.goodreads.com/book/show/5107.The_Catcher_in_the_Rye'
popular_df.at[62, 'book-link'] = 'https://www.goodreads.com/book/show/12232938-the-lovely-bones'
popular_df.at[63, 'book-link'] = 'https://www.goodreads.com/book/show/61439040-1984'
popular_df.at[72, 'book-link'] = 'https://www.goodreads.com/book/show/14249.Prodigal_Summer'
popular_df.at[73, 'book-link'] = 'https://www.goodreads.com/book/show/39821861-neverwhere'
popular_df.at[78, 'book-link'] = 'https://www.goodreads.com/book/show/37435.The_Secret_Life_of_Bees'
popular_df.at[84, 'book-link'] = 'https://www.goodreads.com/book/show/869647.Stupid_White_Men_Other_Sorry_Excuses_for_the_State_of_the_Nation'
popular_df.at[85, 'book-link'] = 'https://www.goodreads.com/book/show/546384.Tuesdays_with_Morrie'
popular_df.at[88, 'book-link'] = 'https://openlibrary.org/books/OL8459036M/Red_Tent_(Bestselling_Backlist)'
popular_df.at[89, 'book-link'] = 'https://www.goodreads.com/book/show/386162.The_Hitchhiker_s_Guide_to_the_Galaxy'
popular_df.at[98, 'book-link'] = 'https://www.goodreads.com/book/show/1869.Nickel_and_Dimed'
popular_df.at[100, 'book-link'] = 'https://www.goodreads.com/book/show/1845.Into_the_Wild'
popular_df.at[103, 'book-link'] = 'https://www.goodreads.com/book/show/13079982-fahrenheit-451'
popular_df.at[116, 'book-link'] = 'https://www.goodreads.com/book/show/2865.Girl_with_a_Pearl_Earring'
popular_df.at[117, 'book-link'] = 'https://www.goodreads.com/book/show/685403.Outlander'
popular_df.at[123, 'book-link'] = 'https://www.goodreads.com/book/show/5168.Where_the_Heart_Is'
popular_df.at[124, 'book-link'] = 'https://www.goodreads.com/book/show/110737.Seabiscuit'
popular_df.at[126, 'book-link'] = 'https://www.goodreads.com/book/show/4214.Life_of_Pi'
popular_df.at[130, 'book-link'] = 'https://www.goodreads.com/book/show/30868.The_Bean_Trees'
popular_df.at[133, 'book-link'] = 'https://books.google.co.in/books/about/A_Child_Called_It.html?id=18xkvEKR9tsC&redir_esc=y'
popular_df.at[135, 'book-link'] = 'https://www.goodreads.com/book/show/252577.Angela_s_Ashes'
popular_df.at[137, 'book-link'] = 'https://www.goodreads.com/book/show/14748.Good_in_Bed'
popular_df.at[139, 'book-link'] = 'https://www.goodreads.com/book/show/1097.Fast_Food_Nation'
popular_df.at[140, 'book-link'] = 'https://www.goodreads.com/book/show/30165203-american-gods'
popular_df.at[141, 'book-link'] = 'https://www.goodreads.com/book/show/5357.Skipping_Christmas'
popular_df.at[147, 'book-link'] = 'https://www.goodreads.com/book/show/160456.Left_Behind'
popular_df.at[149, 'book-link'] = 'https://www.goodreads.com/book/show/119322.The_Golden_Compass'
popular_df.at[157, 'book-link'] = 'https://www.goodreads.com/book/show/52892857-the-color-purple'
popular_df.at[163, 'book-link'] = 'https://www.goodreads.com/book/show/23807.The_Silence_of_the_Lambs'
popular_df.at[166, 'book-link'] = 'https://booksvooks.com/about-a-boy-pdf-nick-hornby-2.html'
popular_df.at[173, 'book-link'] = 'https://www.goodreads.com/book/show/6424.Seven_Up'
popular_df.at[175, 'book-link'] = 'https://www.goodreads.com/book/show/20910195-the-alchemist'
popular_df.at[177, 'book-link'] = 'https://www.goodreads.com/book/show/6425.Hard_Eight'
popular_df.at[182, 'book-link'] = 'https://www.goodreads.com/book/show/7494.Suzanne_s_Diary_for_Nicholas'
popular_df.at[186, 'book-link'] = 'https://www.goodreads.com/book/show/7624.Lord_of_the_Flies'
popular_df.at[192, 'book-link'] = 'https://www.goodreads.com/book/show/4473.A_Prayer_for_Owen_Meany'
popular_df.at[194, 'book-link'] = 'https://www.goodreads.com/book/show/45437968-the-vampire-lestat'
popular_df.at[195, 'book-link'] = 'https://www.goodreads.com/book/show/19431982-white-oleander'

# %%
popular_df
# Out:
#                                             Book-Title  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)
# 3         Harry Potter and the Goblet of Fire (Book 4)
# 5       Harry Potter and the Sorcerer's Stone (Book 1)
# 9    Harry Potter and the Order of the Phoenix (Boo...
# 13    Harry Potter and the Chamber of Secrets (Book 2)
# 16   The Hobbit : The Enchanting Prelude to The Lor...
# 17   The Fellowship of the Ring (The Lord of the Ri...
# 26   Harry Potter and the Sorcerer's Stone (Harry P...
# 28      The Two Towers (The Lord of the Rings, Part 2)
# 39                               To Kill a Mockingbird
# 47                                   The Da Vinci Code
# 53                  The Five People You Meet in Heaven
# 55                              The Catcher in the Rye
# 62                           The Lovely Bones: A Novel
# 63                                                1984
# 72                            Prodigal Summer: A Novel
# ...

# %%
popular_df['book-path'][0]
# Out:
# 'assets/book_image/No_image.jpg'

# %%
popular_df.loc[0, 'book-path'] = 'assets/book_image/hp_prisoner.jpg'
popular_df.loc[3, 'book-path'] = 'assets/book_image/hp_prisoner3.jpg'
popular_df.loc[5, 'book-path'] = 'assets/book_image/hp_prisoner5.jpg'
popular_df.loc[9, 'book-path'] = 'assets/book_image/hp_prisoner9.jpg'
popular_df.loc[13, 'book-path'] = 'assets/book_image/hp_prisoner13.jpg'
popular_df.loc[16, 'book-path'] = 'assets/book_image/hp_prisoner16.jpg'
popular_df.loc[17, 'book-path'] = 'assets/book_image/hp_prisoner17.jpg'
popular_df.loc[26, 'book-path'] = 'assets/book_image/hp_prisoner26.jpg'
popular_df.loc[28, 'book-path'] = 'assets/book_image/hp_prisoner28.jpg'
popular_df.loc[39, 'book-path'] = 'assets/book_image/hp_prisoner39.jpg'
popular_df.loc[47, 'book-path'] = 'assets/book_image/hp_prisoner47.jpg'
popular_df.loc[53, 'book-path'] = 'assets/book_image/hp_prisoner53.jpg'
popular_df.loc[55, 'book-path'] = 'assets/book_image/hp_prisoner55.jpg'
popular_df.loc[62, 'book-path'] = 'assets/book_image/hp_prisoner62.jpg'
popular_df.loc[63, 'book-path'] = 'assets/book_image/hp_prisoner63.jpg'
popular_df.loc[72, 'book-path'] = 'assets/book_image/hp_prisoner72.jpg'
popular_df.loc[73, 'book-path'] = 'assets/book_image/hp_prisoner73.jpg'
popular_df.loc[78, 'book-path'] = 'assets/book_image/hp_prisoner78.jpg'
popular_df.loc[84, 'book-path'] = 'assets/book_image/hp_prisoner84.jpg'
popular_df.loc[85, 'book-path'] = 'assets/book_image/hp_prisoner85.jpg'
popular_df.loc[88, 'book-path'] = 'assets/book_image/hp_prisoner88.jpg'
popular_df.loc[89, 'book-path'] = 'assets/book_image/hp_prisoner89.jpg'
popular_df.loc[98, 'book-path'] = 'assets/book_image/hp_prisoner98.jpg'
popular_df.loc[100, 'book-path'] = 'assets/book_image/hp_prisoner100.jpg'
popular_df.loc[103, 'book-path'] = 'assets/book_image/hp_prisoner103.jpg'
popular_df.loc[116, 'book-path'] = 'assets/book_image/hp_prisoner116.jpg'
popular_df.loc[117, 'book-path'] = 'assets/book_image/hp_prisoner117.jpg'
popular_df.loc[123, 'book-path'] = 'assets/book_image/hp_prisoner123.jpg'
popular_df.loc[124, 'book-path'] = 'assets/book_image/hp_prisoner124.jpg'
popular_df.loc[126, 'book-path'] = 'assets/book_image/hp_prisoner126.jpg'
popular_df.loc[130, 'book-path'] = 'assets/book_image/hp_prisoner130.jpg'
popular_df.loc[133, 'book-path'] = 'assets/book_image/hp_prisoner133.jpg'
popular_df.loc[135, 'book-path'] = 'assets/book_image/hp_prisoner135.jpg'
popular_df.loc[137, 'book-path'] = 'assets/book_image/hp_prisoner137.jpg'
popular_df.loc[139, 'book-path'] = 'assets/book_image/hp_prisoner139.jpg'
popular_df.loc[140, 'book-path'] = 'assets/book_image/hp_prisoner140.jpg'
popular_df.loc[141, 'book-path'] = 'assets/book_image/hp_prisoner141.jpg'
popular_df.loc[147, 'book-path'] = 'assets/book_image/hp_prisoner147.jpg'
popular_df.loc[149, 'book-path'] = 'assets/book_image/hp_prisoner149.jpg'
popular_df.loc[157, 'book-path'] = 'assets/book_image/hp_prisoner157.jpg'
popular_df.loc[163, 'book-path'] = 'assets/book_image/hp_prisoner163.jpg'
popular_df.loc[166, 'book-path'] = 'assets/book_image/hp_prisoner166.jpg'
popular_df.loc[173, 'book-path'] = 'assets/book_image/hp_prisoner173.jpg'
popular_df.loc[175, 'book-path'] = 'assets/book_image/hp_prisoner175.jpg'
popular_df.loc[177, 'book-path'] = 'assets/book_image/hp_prisoner177.jpg'
popular_df.loc[182, 'book-path'] = 'assets/book_image/hp_prisoner182.jpg'
popular_df.loc[186, 'book-path'] = 'assets/book_image/hp_prisoner186.jpg'
popular_df.loc[192, 'book-path'] = 'assets/book_image/hp_prisoner192.jpg'
popular_df.loc[194, 'book-path'] = 'assets/book_image/hp_prisoner194.jpg'
popular_df.loc[195, 'book-path'] = 'assets/book_image/hp_prisoner195.jpg'
popular_df.to_csv('books1.csv', index=False)

# %%
popular_df
# Out:
#                                             Book-Title  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)
# 3         Harry Potter and the Goblet of Fire (Book 4)
# 5       Harry Potter and the Sorcerer's Stone (Book 1)
# 9    Harry Potter and the Order of the Phoenix (Boo...
# 13    Harry Potter and the Chamber of Secrets (Book 2)
# 16   The Hobbit : The Enchanting Prelude to The Lor...
# 17   The Fellowship of the Ring (The Lord of the Ri...
# 26   Harry Potter and the Sorcerer's Stone (Harry P...
# 28      The Two Towers (The Lord of the Rings, Part 2)
# 39                               To Kill a Mockingbird
# 47                                   The Da Vinci Code
# 53                  The Five People You Meet in Heaven
# 55                              The Catcher in the Rye
# 62                           The Lovely Bones: A Novel
# 63                                                1984
# 72                            Prodigal Summer: A Novel
# ...

# %%
import pickle
pickle.dump(popular_df, open('popular.pkl', 'wb'))

# %% [markdown]
# # Collborative Filtering Based

# %%
ratings_with_name.groupby('User-ID').count()['Book-Rating']## user with how many votes
# Out:
# User-ID
# 2          1
# 8         17
# 9          3
# 10         1
# 12         1
#           ..
# 278846     1
# 278849     4
# 278851    23
# 278852     1
# 278854     8
# Name: Book-Rating, Length: 92106, dtype: int64

# %%
x=ratings_with_name.groupby('User-ID').count()['Book-Rating']>200
knowledgeable_users = x[x].index  ## users who votes minimum 200 books

# %%
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(knowledgeable_users)]
filtered_rating
# Out:
#          User-ID        ISBN  Book-Rating  \
# 2           6543  034545104X            0
# 5          23768  034545104X            0
# 7          28523  034545104X            0
# 15         77940  034545104X            0
# 16         81977  034545104X            0
# ...          ...         ...          ...
# 1030883   275970  1880837927            0
# 1030884   275970  188717897X            0
# 1030885   275970  1888889047            0
# 1030886   275970  1931868123            0
# 1030887   275970  3411086211           10
#
#                                                 Book-Title  \
# 2                                     Flesh Tones: A Novel
# 5                                     Flesh Tones: A Novel
# 7                                     Flesh Tones: A Novel
# 15                                    Flesh Tones: A Novel
# 16                                    Flesh Tones: A Novel
# ...                                                    ...
# ...

# %%
y=filtered_rating.groupby('Book-Title').count()['Book-Rating']>=50
famous_books=y[y].index
famous_books
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Day Late and a Dollar Short', 'A Fine Balance',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='Book-Title', length=706)

# %%
final_ratings =filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (706, 706)

# %%
index= np.where(pt.index=='1st to Die:  Novel')[0][0]# calculating index of a book
index
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_820/1879916166.py in <module>
# ----> 1 index= np.where(pt.index=='1st to Die:  Novel')[0][0]# calculating index of a book
#       2 index
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
def recommend(book_name):
    # index fetch
    index= np.where(pt.index==book_name)[0][0]# calculating index of a book
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[0:6] # similarity of 1984 book with other books
    
    data = []
    for i in similar_items:
        item=[]
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['book-path'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['book-link'].values))
        
        data.append(item)
    return data

# %%
recommend('1984')
# Out:
# [['1984', 'George Orwell', 'assets/book_image/No_image.jpg', '#'],
#  ['Animal Farm', 'George Orwell', 'assets/book_image/No_image.jpg', '#'],
#  ["The Handmaid's Tale",
#   'Margaret Atwood',
#   'assets/book_image/No_image.jpg',
#   '#'],
#  ['Brave New World', 'Aldous Huxley', 'assets/book_image/No_image.jpg', '#'],
#  ['The Vampire Lestat (Vampire Chronicles, Book II)',
#   'ANNE RICE',
#   'assets/book_image/No_image.jpg',
#   '#'],
#  ['The Hours : A Novel',
#   'Michael Cunningham',
#   'assets/book_image/No_image.jpg',
#   '#']]

# %%
pickle.dump(pt,open('pts1.pkl','wb'))
pickle.dump(books,open('books1.pkl','wb'))
pickle.dump(similarity_scores,open('similarity_scores1.pkl','wb'))
